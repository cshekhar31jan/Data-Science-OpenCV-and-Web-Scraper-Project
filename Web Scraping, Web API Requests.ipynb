# %% [markdown]
# ### How to call an API :-

# %%
# !pip install requests
# Out:
# ...
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: You are using pip version 21.2.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Python310\python.exe -m pip install --upgrade pip' command.
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# ...
#   Using cached certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
# ...

# %%
import requests
import json

# %% [markdown]
# ## get data from API

# %%
url = "https://www.boredapi.com/api/activity"

# %%
res= requests.get(url)
# Here , response is stored in "res" variable and

# %%
res.status_code
# Out:
# 200

# %%
type(res.text)
# Out:
# str

# %%
res.text
# Out:
# '{"activity":"Fill out a basketball bracket","type":"recreational","participants":1,"price":0,"link":"","key":"7806284","accessibility":0.1}'

# %%
# import json
activity = json.loads(res.text)
activity['activity']
# Out:
# 'Fill out a basketball bracket'

# %%
url = "https://api.ipify.org"

# %% [markdown]
# ### API to Get public IP address :

# %%
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
res.text
# Out:
# '14.139.38.176'

# %%
url = "http://universities.hipolabs.com/search?country=India"

# %%
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
universities = json.loads(res.text)

# %%
universities
# Out:
# [{'country': 'India',
#   'name': 'University of Petroleum and Energy Studies',
#   'domains': ['upes.ac.in'],
#   'alpha_two_code': 'IN',
#   'state-province': 'Dehradun',
#   'web_pages': ['https://www.upes.ac.in/']},
#  {'country': 'India',
#   'name': 'DAV Institute of Engineering & Technology',
#   'domains': ['davietjal.org'],
#   'alpha_two_code': 'IN',
#   'state-province': 'Punjab',
#   'web_pages': ['http://www.davietjal.org/']},
#  {'country': 'India',
#   'name': 'Lovely Professional University',
#   'domains': ['lpu.in'],
#   'alpha_two_code': 'IN',
#   'state-province': 'Punjab',
#   'web_pages': ['http://www.lpu.in/']},
#  {'country': 'India',
#   'name': 'Somaiya Vidyavihar',
#   'domains': ['somaiya.edu'],
#   'alpha_two_code': 'IN',
#   'state-province': None,
#   'web_pages': ['https://somaiya.edu/']},
#  {'country': 'India',
#   'name': 'NorthCap University',
#   'domains': ['ncuindia.edu'],
#   'alpha_two_code': 'IN',
#   'state-province': 'Haryana',
# ...

# %%
url = "http://api.tvmaze.com/search/shows?q=friends"

# %%
res = requests.get(url)

# %%
shows = json.loads(res.text)
shows
# Out:
# [{'score': 0.9087262,
#   'show': {'id': 431,
#    'url': 'https://www.tvmaze.com/shows/431/friends',
#    'name': 'Friends',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Comedy', 'Romance'],
#    'status': 'Ended',
#    'runtime': 30,
#    'averageRuntime': 30,
#    'premiered': '1994-09-22',
#    'ended': '2004-05-06',
#    'officialSite': None,
#    'schedule': {'time': '20:00', 'days': ['Thursday']},
#    'rating': {'average': 8.6},
#    'weight': 97,
#    'network': {'id': 1,
#     'name': 'NBC',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'},
#     'officialSite': 'https://www.nbc.com/'},
#    'webChannel': None,
#    'dvdCountry': None,
#    'externals': {'tvrage': 3616, 'thetvdb': 79168, 'imdb': 'tt0108778'},
#    'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/41/104550.jpg',
# ...

# %% [markdown]
# # Info about countries :

# %%
url = "https://restcountries.eu/rest/v2/all"

# %%
res = requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File C:\Python310\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File C:\Python310\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File C:\Python310\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ...

# %%
countries = json.loads(res.text)
countries
# Out:
# [{'score': 0.9087262,
#   'show': {'id': 431,
#    'url': 'https://www.tvmaze.com/shows/431/friends',
#    'name': 'Friends',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Comedy', 'Romance'],
#    'status': 'Ended',
#    'runtime': 30,
#    'averageRuntime': 30,
#    'premiered': '1994-09-22',
#    'ended': '2004-05-06',
#    'officialSite': None,
#    'schedule': {'time': '20:00', 'days': ['Thursday']},
#    'rating': {'average': 8.6},
#    'weight': 97,
#    'network': {'id': 1,
#     'name': 'NBC',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'},
#     'officialSite': 'https://www.nbc.com/'},
#    'webChannel': None,
#    'dvdCountry': None,
#    'externals': {'tvrage': 3616, 'thetvdb': 79168, 'imdb': 'tt0108778'},
#    'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/41/104550.jpg',
# ...

# %% [markdown]
# # Image scraping :

# %%
img_url = "https://i.pinimg.com/originals/46/cd/e1/46cde1793ed0e7727ffbf6dc7a7ea189.jpg"
# img_url = "https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.pinterest.com%2Fpin%2F88242473929963089%2F&psig=AOvVaw1U_IqE9web16r7BndILWRL&ust=1648239485675000&source=images&cd=vfe&ved=0CAsQjRxqFwoTCLjM9NzI3_YCFQAAAAAdAAAAABAD"
# The above lines will get executed but you will not get the image saved because you have copied "Cpoy link address " dont copy this better copy "copy image address"

# %%
res = requests.get(img_url)

# %%
res.status_code
# Out:
# 200

# %% [markdown]
# ### Here, If you write res.text, It will give you the data but you cant understand much so You need to write res.content in order to get a binary data :

# %%
res.text
# Out:
# '����\x00\x10JFIF\x00\x01\x01\x01\x01,\x01,\x00\x00��\x00C\x00\x06\x04\x05\x06\x05\x04\x06\x06\x05\x06\x07\x07\x06\x08\n\x10\n\n\t\t\n\x14\x0e\x0f\x0c\x10\x17\x14\x18\x18\x17\x14\x16\x16\x1a\x1d%\x1f\x1a\x1b#\x1c\x16\x16 , #&\')*)\x19\x1f-0-(0%()(��\x00C\x01\x07\x07\x07\n\x08\n\x13\n\n\x13(\x1a\x16\x1a((((((((((((((((((((((((((((((((((((((((((((((((((��\x00\x11\x08\x05�\x08I\x03\x01"\x00\x02\x11\x01\x03\x11\x01��\x00\x1b\x00\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x00\x03\x04\x05\x06\x07��\x00\x1b\x01\x00\x03\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07��\x00\x0c\x03\x01\x00\x02\x10\x03\x10\x00\x00\x01�\x06N?nV��P��d)�B4KU�\x0bCT�V���$`W\x02\x06\x16B,N�r�p�H#\tVh�\x13%H�\x02�2\nI\x04�\x0bO\x14��\x0b-dy�A�!\x05;i��L�B���UZk[��%=)ys\'O\x1e��[�\\\x10�Ҵ,\x02�\x15�\x16�#�\x16-��5�ʃ-�\x01�\x06A\x19#R\x08"T�H-B\x0b\x0c�\t\x11\x12\x02�\x0c\x04��BH%\x04\x00\x04\n\x18D\x18\x170\x10\x00�����ƣ\x06i�,r�cH���!P0\x04\x10"\x0
# ...

# %%
res.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x01,\x01,\x00\x00\xff\xdb\x00C\x00\x06\x04\x05\x06\x05\x04\x06\x06\x05\x06\x07\x07\x06\x08\n\x10\n\n\t\t\n\x14\x0e\x0f\x0c\x10\x17\x14\x18\x18\x17\x14\x16\x16\x1a\x1d%\x1f\x1a\x1b#\x1c\x16\x16 , #&\')*)\x19\x1f-0-(0%()(\xff\xdb\x00C\x01\x07\x07\x07\n\x08\n\x13\n\n\x13(\x1a\x16\x1a((((((((((((((((((((((((((((((((((((((((((((((((((\xff\xc2\x00\x11\x08\x05\x86\x08I\x03\x01"N?nV\xf1\xcdP\x8a\x96d)\xbaB4KU\xca\x0bCT\x8bV\xa6\xb0\xe1\xa9$`W\x02\x06\x16B,N\xb1r\x85p\xc1H#\tVh\xc9\x13%H\xde\x02\xdc2\nI\x04\xc5\x0bO\x14\xb1\x99\x0b-dy\xb2A\x9d!\x05;i\xb1\xe7L\xe3B\xb9\xa6\xe5UZk[\xb3\xd7%=)ys\'O\x1e\x98\xe7[\x97\\\x10\x98\xd2\xb
# ...

# %%
binary_img_data = res.content

# %%
with open("landscape.jpg", 'wb') as f:
    f.write(binary_img_data)
